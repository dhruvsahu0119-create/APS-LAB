# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvsahu0119-create/APS-LAB/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
n=len(graph)
for i in range(n-1):
    for j in range(n-1):
         if graph[i][j]<graph[i+1][j+1]:
                print(f"Path of cities visited from {i} to {j}")
# Out:
# Path of cities visited from 0 to 1
# Path of cities visited from 0 to 2
# Path of cities visited from 1 to 0
# Path of cities visited from 2 to 0

# %%
a=int(input("Enter the no of vertex:"))
for i in range(a):
  for j in range(a):
       graph[i][j]=int(input("Enter a cost "))

for i in range(a):
  for j in range(a):
    print(graph[i][j],end=" ")
  print()
print("Minimun travelling cost:", tsp(graph))
# Out:
# Enter the no of vertex:4
# Enter a cost 10
# Enter a cost 0
# Enter a cost 15
# Enter a cost 16
# Enter a cost 7
# Enter a cost 8
# Enter a cost 17
# Enter a cost 13
# Enter a cost 10
# Enter a cost 0
# Enter a cost 0
# Enter a cost 0
# Enter a cost 11
# Enter a cost 14
# Enter a cost 18
# Enter a cost 22
# 10 0 15 16
# 7 8 17 13
# 10 0 0 0
# 11 14 18 22
# Minimun travelling cost: 28

# %%
print("Test case 1")
a=int(input("Enter the no of cities to visited: "))
for i in range(a):
  for j in range(a):
     graph[i][j]=int(input("Enter a cost of each way to travel "))

print("Minimun travelling cost:", tsp(graph))

print("Test case 2")
b=int(input("Enter the no of cities to visited: "))
for i in range(b):
  for j in range(b):
     graph[i][j]=int(input("Enter a cost of each way to travel "))

print("Minimun travelling cost:", tsp(graph))

print("Test case 3")
c=int(input("Enter the no of cities to visited: "))
for i in range(c):
  for j in range(c):
     graph[i][j]=int(input("Enter a cost of each way to travel "))

print("Minimun travelling cost:", tsp(graph))
# Out:
# Test case 1
# Enter the no of cities to visited: 2
# Enter a cost of each way to travel 00
# Enter a cost of each way to travel 06
# Enter a cost of each way to travel 70
# Enter a cost of each way to travel 16
# Minimun travelling cost: 34
# Test case 2
# Enter the no of cities to visited: 1
# Enter a cost of each way to travel 02
# Minimun travelling cost: 34
# Test case 3
# Enter the no of cities to visited: 3
# Enter a cost of each way to travel 12
# Enter a cost of each way to travel 13
# Enter a cost of each way to travel 00
# Enter a cost of each way to travel 00
# Enter a cost of each way to travel 18
# Enter a cost of each way to travel 19
# Enter a cost of each way to travel 20
# Enter a cost of each way to travel 77
# Enter a cost of each way to travel 42
# Minimun travelling cost: 14
